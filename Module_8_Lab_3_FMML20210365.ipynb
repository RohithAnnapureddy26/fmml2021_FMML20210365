# %% [markdown]
# <a href="https://colab.research.google.com/github/RohithAnnapureddy26/fmml2021_FMML20210365/blob/main/Module_8_Lab_3_FMML20210365.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2022-06-08 16:01:37--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.108.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   285MB/s    in 0.2s
#
# 2022-06-08 16:01:38 (285 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False), 
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split() 
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 26993  1701.07717v5  The main contribution of this paper is a simpl...    cs
# 6399   1701.02960v2  Markov chain Monte Carlo (MCMC) algorithms are...    cs
# 11743  1611.00938v2  We focus in this work on the estimation of the...    cs
# 21623   1203.5647v1  This paper describes a novel method to approxi...  stat
# 33889  1803.05383v1  The inherent transient dynamics of recurrent n...    cs
# ...             ...                                                ...   ...
# 37851   0901.2730v1  In this paper, we present a novel and general ...  stat
# 24713   1411.0442v1  As the features from the traditional Local Bin...    cs
# 8107    1406.3010v2  The human visual system is able to recognize o...    cs
# 12325  1711.08797v1  Hashing is a basic tool for dimensionality red...  stat
# 25262  1507.00110v1  For polarimetric SAR (PolSAR) image classifica...    cs
#
#                                                    title  year  \
# 26993  Unlabeled Samples Generated by GAN Improve the...  2017
# 6399         Fast mixing for Latent Dirichlet allocation  2017
# 11743  Fast Eigenspace Approximation using Random Sig...  2016
# 21623  Polynomial expansion of the binary classificat...  2012
# 33889  Use of recurrent infomax to improve the memory...  2018
# ...                                                  ...   ...
# 37851     Maximum Entropy Discrimination Markov Networks  2009
# 24713  Non Binary Local Gradient Contours for Face Re...  2014
# 8107   "Mental Rotation" by Optimizing Transforming D...  2014
# 12325  Practical Hash Functions for Similarity Estima...  2017
# 25262  Polarimetric Hierarchical Semantic Model and S...  2015
#
#                                                 keywords
# 26993  [contribution, supervised, collecting, challen...
# 6399   [algorithms, ubiquitous, probability, particul...
# 11743  [estimation, eigenvectors, laplacian, filterin...
# 21623  [describes, approximate, polynomial, coefficie...
# 33889  [transient, recurrent, exploited, computationa...
# ...                                                  ...
# 37851  [framework, discrimination, integrates, struct...
# 24713  [traditional, directional, ineffective, recogn...
# 8107   [recognize, transformations, drastically, appe...
# 12325  [dimensionality, reduction, perfomance, assump...
# 25262  [polarimetric, classification, challenge, aggr...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 26993    [contribution, supervised, collecting, challen...
# 6399     [algorithms, ubiquitous, probability, particul...
# 11743    [estimation, eigenvectors, laplacian, filterin...
# 21623    [describes, approximate, polynomial, coefficie...
# 33889    [transient, recurrent, exploited, computationa...
#                                ...
# 13350    [successfully, application, involving, classif...
# 3924     [paedomorphosis, biological, retention, morpho...
# 3929     [algorithm, diversity, population, particularl...
# 7016     [technical, hopefully, pedagogical, architectu...
# 22563    [personalized, treatment, increased, therapies...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]), 
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8968 words.
# Out of those 4608 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="7ee097fa-660a-4865-af63-f347fc323cdb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7ee097fa-660a-4865-af63-f347fc323cdb")) {                    Plotly.newPlot(                        "7ee097fa-660a-4865-af63-f347fc323cdb",                        [{"x":["contribution","challenging","discriminative","smoothing","adversarial","regularizes","collecting","convolutional","additionally","recognition","precision","generative","generated","regularization","embeddings","available","supervised","generation","identification","representation","improvement","unlabeled","distribution","practical","respectively","effectively","experiments","unsupervised","documents","particular","stationary","dirichlet","represented","corresponds","classification","algorithms","ubiquitous","theoretical","allocation","stationarity","computations","intractable","posterior","different","guarantees","probability","vocabulary","eigenspace","approximated","approximation","filtering","reconstruction","assumption","determination","laplacian","clustering","eigenvectors","achieving","eigenvalue","synthetic","visualization","regardless","estimation","implementing","extremely","efficient","dimensional","polynomial","approximate","coefficients","derivation","expansion","functions","resistant","describes","regression","technique","structure","connection","computational","possesses","properties","capability","maximizes","investigated","optimized","transient","depending","processing","information","adjusting","relevance","recurrent","exploited","strengths","intelligence","conference","proceedings","artificial","uncertainty","efficiency","propagation","quantitatively","propagate","specifically","developed","efficiencies","improvements","initially","automatic","applications","scenarios","interactive","application","perspective","throughout","exponential","significant","bilateral","presented","computation","experimented","qualitatively","multimedia","segmentation","dynamically","classifier","baselines","modifications","attribute","introduce","introduces","detection","performance","framework","demonstrates","demographics","leveraging","accompanied","inclusion","questions","individuals","accompanying","demographic","performing","diversity","improving","simulation","acquisition","conducted","evaluating","variables","environment","continuous","experimental","implemented","localization","integrates","knowledge","sentences","discovery","primitive","nonparametric","estimated","alternatives","formulating","experiment","resulting","selecting","demonstrate","repeatedly","expensive","benchmark","maximizing","alternative","effectiveness","sequential","observations","motivated","consuming","introduced","canonical","penalizing","correlation","relationship","nonlinear","transformations","computing","limitation","multivariate","alleviate","algorithm","statistical","relations","generalization","optimization","characterization","truncated","reduction","converges"],"y":[71,259,92,20,105,3,11,391,62,388,69,127,157,84,74,283,173,135,120,384,147,41,201,137,87,115,582,150,65,277,29,27,90,18,535,559,8,144,29,4,21,25,44,738,60,158,33,4,23,95,68,97,65,14,13,138,10,69,11,131,30,13,214,28,55,367,174,70,103,39,11,17,207,4,68,99,255,345,44,296,8,217,50,10,47,59,6,42,304,713,9,45,121,29,21,77,18,7,126,86,158,70,21,6,157,182,2,128,11,204,418,81,43,239,79,18,43,242,7,192,141,9,17,18,218,28,148,56,15,38,323,77,350,861,554,57,4,48,12,12,75,44,7,6,76,45,118,80,43,79,55,129,135,125,344,90,75,23,369,77,59,9,21,52,35,4,60,135,47,568,8,63,212,28,99,196,65,72,49,38,133,17,4,69,75,67,40,122,28,16,31,734,142,90,122,336,27,3,95,19],"type":"bar"},{"x":["contribution","challenging","discriminative","smoothing","adversarial","reg ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4608,), (4608, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8225

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.5128205128205128);'>Improving</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Reliability</span> <span style=''>of</span> <span style=''>Word</span> <span style='background-color:rgba(0, 255, 0, 0.37692307692307697);'>Similarity</span> <span style='background-color:rgba(0, 255, 0, 0.4269340974212035);'>Evaluation</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>Redesigning</span> <span style='background-color:rgba(0, 255, 0, 0.8545454545454545);'>Annotation</span> <span style=''>Task</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Performance</span> <span style=''>Measure</span> <br/><br/><span style=''>We</span> <span style=''>suggest</span> <span style=''>a</span> <span style=''>new</span> <span style=''>method</span> <span style=''>for</span> <span style=''>creating</span> <span style=''>and</span> <span style=''>using</span> <span style=''>gold</span> <span style=''>standard</span> <span style=''>datasets</span> <span style=''>for</span> <span style=''>word</span> <span style='background-color:rgba(0, 255, 0, 0.37692307692307697);'>similarity</span> <span style='background-color:rgba(0, 255, 0, 0.4269340974212035);'>evaluation</span> <span style=''>Our</span> <span style=''>goal</span> <span style=''>is</span> <span style=''>to</span> <span style=''>improve</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>reliability</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.4269340974212035);'>evaluation</span> <span style=''>and</span> <span style=''>we</span> <span style=''>do</span> <span style=''>this</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>redesigning</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.8545454545454545);'>annotation</span> <span style=''>task</span> <span style=''>to</span> <span style=''>achieve</span> <span style=''>higher</span> <span style=''>inter</span> <span style=''>rater</span> <span style='background-color:rgba(0, 255, 0, 0.47368421052631576);'>agreement</span> <span style=''>and</span> <span style=''>by</span> <span style=''>defining</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style=''>measure</span> <span style=''>which</span> <span style=''>takes</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>reliability</span> <span style=''>of</span> <span style=''>each</span> <span style='background-color:rgba(0, 255, 0, 0.8545454545454545);'>annotation</span> <span style=''>decision</span> <span style=''>in</span> <span style=''>the</span> <span style=''>dataset</span> <span style=''>into</span> <span style=''>account</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Robust</span> <span style=''>Learning</span> <span style=''>for</span> <span style=''>Optimal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Treatment</span> <span style=''>Decision</span> <span style=''>with</span> <span style=''>NP</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Dimensionality</span> <br/><br/><span style=''>In</span> <span style=''>order</span> <span style=''>to</span> <span style=''>identify</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>important</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variables</span> <span style=''>that</span> <span style=''>are</span> <span style=''>involved</span> <span style=''>in</span> <span style=''>making</span> <span style=''>optimal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>treatment</span> <span style=''>decision</span> <span style=''>Lu</span> <span style=''>et</span> <span style=''>al</span> <span style=''>(2013)</span> <span style=''>proposed</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>penalized</span> <span style=''>least</span> <span style=''>squared</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regression</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>for</span> <span style=''>a</span> <span style=''>fixed</span> <span style=''>number</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>predictors</span> <span style=''>which</span> <span style=''>is</span> <span style=''>robust</span> <span style=''>against</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>misspecification</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>conditional</span> <span style=''>mean</span> <span style=''>model</span> <span style=''>Two</span> <span style=''>problems</span> <span style=''>arise</span> <span style=''>(i)</span> <span style=''>in</span> <span style=''>a</span> <span style=''>world</span> <span style=''>of</span> <span style=''>explosively</span> <span style=''>big</span> <span style=''>data</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>effective</span> <span style=''>methods</span> <span style=''>are</span> <span style=''>needed</span> <span style=''>to</span> <span style=''>handle</span> <span style=''>ultra</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style=''>data</span> <span style=''>set</span> <span style=''>for</span> <span style=''>example</span> <span style=''>with</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimension</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>predictors</span> <span style=''>is</span> <span style=''>of</span> <span style=''>the</span> <span style=''>non</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>polynomial</span> <span style=''>(NP)</span> <span style=''>order</span> <span style=''>of</span> <span style=''>the</span> <span style=''>sample</span> <span style=''>size</span> <span style=''>(ii)</span> <span style=''>both</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>propensity</span> <span style=''>score</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>conditional</span> <span style=''>mean</span> <span style=''>models</span> <span style=''>need</span> <span style=''>to</span> <span style=''>be</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimated</span> <span style=''>from</span> <span style=''>data</span> <span style=''>under</span> <span style=''>NP</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensionality</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>propose</span> <span st ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Nonlinear</span> <span style='background-color:rgba(0, 255, 0, 0.3034734917733089);'>Information</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Bottleneck</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.3034734917733089);'>Information</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>bottleneck</span> <span style=''>IB</span> <span style=''>is</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>technique</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.4666666666666667);'>extracting</span> <span style='background-color:rgba(0, 255, 0, 0.3034734917733089);'>information</span> <span style=''>in</span> <span style=''>some</span> <span style=''>input</span> <span style=''>random</span> <span style=''>variable</span> <span style=''>that</span> <span style=''>is</span> <span style=''>relevant</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>predicting</span> <span style=''>some</span> <span style='background-color:rgba(0, 255, 0, 0.3155080213903743);'>different</span> <span style=''>output</span> <span style=''>random</span> <span style=''>variable</span> <span style=''>IB</span> <span style=''>works</span> <span style=''>by</span> <span style=''>encoding</span> <span style=''>the</span> <span style=''>input</span> <span style=''>in</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>compressed</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>bottleneck</span> <span style=''>variable</span> <span style=''>from</span> <span style=''>which</span> <span style=''>the</span> <span style=''>output</span> <span style=''>can</span> <span style=''>then</span> <span style=''>be</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>accurately</span> <span style=''>decoded</span> <span style=''>IB</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>difficult</span> <span style=''>to</span> <span style=''>compute</span> <span style=''>in</span> <span style=''>practice</span> <span style=''>and</span> <span style=''>has</span> <span style=''>been</span> <span style=''>mainly</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>developed</span> <span style=''>for</span> <span style=''>two</span> <span style=''>limited</span> <span style=''>cases</span> <span style=''>(1)</span> <span style=''>discrete</span> <span style=''>random</span> <span style='background-color:rgba(255, 0, 0, 0.3613861386138613);'>variables</span> <span style=''>with</span> <span style=''>small</span> <span style=''>state</span> <span style=''>spaces</span> <span style=''>and</span> <span style=''>(2)</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>continuous</span> <span style=''>random</span> <span style='background-color:rgba(255, 0, 0, 0.3613861386138613);'>variables</span> <span style=''>that</span> <span style=''>are</span> <span style=''>jointly</span> <span style=''>Gaussian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distributed</span> <span style=''>(in</span> <span style=''>which</span> <span style=''>case</span> <span style=''>the</span> <span style=''>encoding</span> <span style=''>and</span> <span style=''>decoding</span> <span style=''>maps</span> <span style=''>are</span> <span style=''>linear)</span> <span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>method</span> <span style=''>to</span> <span style=''>perform</span> <span style=''>IB</span> <span style=''>in</span> <span style=''>more</span> <span style=''>general</span> <span style=''>domains</span> <span style=''>Our</span> <span style=''>approach</span> <span style=''>can</span> <span style=''>be</span> <span style=''>applied</span> <span style=''>to</span> <span style=''>discrete</span> <span style=''>or</span> <span style='backg ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Learning</span> <span style=''>Role</span> <span style=''>based</span> <span style=''>Graph</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Embeddings</span> <br/><br/><span style=''>Random</span> <span style=''>walks</span> <span style=''>are</span> <span style=''>at</span> <span style=''>the</span> <span style=''>heart</span> <span style=''>of</span> <span style=''>many</span> <span style=''>existing</span> <span style=''>network</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>embedding</span> <span style=''>methods</span> <span style=''>However</span> <span style=''>such</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>have</span> <span style=''>many</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>limitations</span> <span style=''>that</span> <span style=''>arise</span> <span style=''>from</span> <span style=''>the</span> <span style=''>use</span> <span style=''>of</span> <span style=''>random</span> <span style=''>walks</span> <span style=''>eg</span> <span style=''>the</span> <span style=''>features</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>resulting</span> <span style=''>from</span> <span style=''>these</span> <span style=''>methods</span> <span style=''>are</span> <span style=''>unable</span> <span style=''>to</span> <span style=''>transfer</span> <span style=''>to</span> <span style=''>new</span> <span style=''>nodes</span> <span style=''>and</span> <span style=''>graphs</span> <span style=''>as</span> <span style=''>they</span> <span style=''>are</span> <span style=''>tied</span> <span style=''>to</span> <span style=''>vertex</span> <span style=''>identity</span> <span style=''>In</span> <span style=''>this</span> <span style=''>work</span> <span style=''>we</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduce</span> <span style=''>the</span> <span style=''>Role2Vec</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>which</span> <span style=''>uses</span> <span style=''>the</span> <span style=''>flexible</span> <span style=''>notion</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>attributed</span> <span style=''>random</span> <span style=''>walks</span> <span style=''>and</span> <span style=''>serves</span> <span style=''>as</span> <span style=''>a</span> <span style=''>basis</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generalizing</span> <span style=''>existing</span> <span style=''>methods</span> <span style=''>such</span> <span style=''>as</span> <span style=''>DeepWalk</span> <span style=''>node2vec</span> <span style=''>and</span> <span style=''>many</span> <span style=''>others</span> <span style=''>that</span> <span style=''>leverage</span> <span style=''>random</span> <span style=''>walks</span> <span style=''>Our</span> <span style=''>proposed</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>enables</span> <span style=''>these</span> <span style=''>methods</span> <span style=''>to</span> <span style=''>be</span> <span style=''>more</span> <span style=''>widely</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>applicable</span> <span style=''>for</span> <span style=''>both</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>transductive</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inductive</span> <span style=''>learning</span> <span style=''>as</span> <span style=''>well</span> <span style=''>as</span> <span style=''>for</span> <span style=''>use</span> <span style=''>on</span> <span style=''>graphs</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>attributes</span> <span style=''>(if</span> <span style=''>available)</span> <span style=''>This</span> <span style=''>is</span> <span style=''>achieved</span> <span style=''>by</spa ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	processing (0.10861021793497677)
# 	architecture (0.08717399071096821)
# 	knowledge (0.13183279742765272)
# 	representation (0.13719185423365488)
# 	segmentation (0.07788495891389782)
# 	information (0.25473383351196854)
# 	different (0.26366559485530544)
# 	detection (0.1250446588067167)
# 	convolutional (0.1396927474097892)
# 	recognition (0.13862093604858877)
#
# Some Statistics words are:
# 	variables (0.1374312843578211)
# 	stochastic (0.13793103448275862)
# 	estimation (0.17341329335332334)
# 	theoretical (0.14942528735632185)
# 	statistical (0.15242378810594703)
# 	distribution (0.19590204897551225)
# 	algorithm (0.39080459770114945)
# 	inference (0.19440279860069964)
# 	dimensional (0.20339830084957522)
# 	regression (0.18590704647676162)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]), 
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="44cddef4-d835-4d95-92a9-ab3badd3ebc6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("44cddef4-d835-4d95-92a9-ab3badd3ebc6")) {                    Plotly.newPlot(                        "44cddef4-d835-4d95-92a9-ab3badd3ebc6",                        [{"x":["contribution","challenging","discriminative","smoothing","adversarial","regularizes","collecting","convolutional","additionally","recognition","precision","generative","generated","regularization","embeddings","available","supervised","generation","identification","representation","improvement","unlabeled","distribution","practical","respectively","effectively","experiments","unsupervised","documents","particular","stationary","dirichlet","represented","corresponds","classification","algorithms","ubiquitous","theoretical","allocation","stationarity","computations","intractable","posterior","different","guarantees","probability","vocabulary","eigenspace","approximated","approximation","filtering","reconstruction","assumption","determination","laplacian","clustering","eigenvectors","achieving","eigenvalue","synthetic","visualization","regardless","estimation","implementing","extremely","efficient","dimensional","polynomial","approximate","coefficients","derivation","expansion","functions","resistant","describes","regression","technique","structure","connection","computational","possesses","properties","capability","maximizes","investigated","optimized","transient","depending","processing","information","adjusting","relevance","recurrent","exploited","strengths","intelligence","conference","proceedings","artificial","uncertainty","efficiency","propagation","quantitatively","propagate","specifically","developed","efficiencies","improvements","initially","automatic","applications","scenarios","interactive","application","perspective","throughout","exponential","significant","bilateral","presented","computation","experimented","qualitatively","multimedia","segmentation","dynamically","classifier","baselines","modifications","attribute","introduce","introduces","detection","performance","framework","demonstrates","demographics","leveraging","accompanied","inclusion","questions","individuals","accompanying","demographic","performing","diversity","improving","simulation","acquisition","conducted","evaluating","variables","environment","continuous","experimental","implemented","localization","integrates","knowledge","sentences","discovery","primitive","nonparametric","estimated","alternatives","formulating","experiment","resulting","selecting","demonstrate","repeatedly","expensive","benchmark","maximizing","alternative","effectiveness","sequential","observations","motivated","consuming","introduced","canonical","penalizing","correlation","relationship","nonlinear","transformations","computing","limitation","multivariate","alleviate","algorithm","statistical","relations","generalization","optimization","characterization","truncated","reduction","converges","ingredients","unexplored","objective","expression","discriminant","dimension","including","evolution","generalized","convergence","sufficient","numerical","eigenvector","attributes","explanatory","simulations","sensitive","disparate","algorithmic","discriminated","conceptually","correlated","economics","evaluated","discrimination","translational","orientation","illumination","incorporating","estimating","unbounded","egomotion","requiring","reckoning","effective","accumulation","inferring","dedicated","revisited","applicable","hypergraph","approximations","functionals","hypergraphs","conditions","relationships","variation","parameter","attraction","controlled","containing","distances","configuration","empirically","temperature","influences"," ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	explanatory
# 	discriminated
# 	respondents
# 	stimulated
# 	rehabilitation
# 	therapies
# 	uncontaminated
# 	contamination
# 	archetypal
# 	archetypes
# 	inexactly
# 	binarycategorical
# 	specializes
# 	calculable
# 	prioritization
# 	positively
# 	confounders
# 	morgenstern
# 	unconfounded
# 	confounder
# Some words which never appear in Statistics papers:
# 	regularizes
# 	demographics
# 	primitive
# 	illumination
# 	egomotion
# 	reckoning
# 	comprised
# 	assembled
# 	fortunately
# 	conceptnet
# 	radiologists
# 	radiology
# 	fruitfully
# 	calcification
# 	angiography
# 	happiness
# 	resourced
# 	broadcasts
# 	vibration
# 	misinterpretation

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0676728633658504e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7741666666666667
